# %%
dict_rules={}
with open('input_day19.txt', 'r') as file:
    inputs=file.read().split('\n\n')
    inputs1=inputs[0].split('\n')
    inputs2=inputs[1].strip().split('\n')
    
for i in inputs1:
    i=i.split(':')
    dict_rules[i[0]]=i[1].split(' | ')

# %%
def check(number):
    if

# %%
inputs1
# Out:
# ['25: 6 54 | 28 122',
#  '52: 27 54 | 25 122',
#  '44: 118 122 | 30 54',
#  '37: 122 97 | 54 98',
#  '38: 122 22 | 54 3',
#  '77: 54 34 | 122 7',
#  '17: 122 124 | 54 47',
#  '1: 54 79 | 122 119',
#  '13: 122 121 | 54 15',
#  '29: 122 3 | 54 97',
#  '24: 54 97 | 122 62',
#  '80: 122 1 | 54 21',
#  '62: 54 54 | 122 54',
#  '5: 54 61 | 122 119',
#  '28: 54 57 | 122 36',
#  '101: 122 48 | 54 44',
#  '81: 120 54 | 14 122',
#  '14: 54 96 | 122 38',
#  '18: 40 122 | 76 54',
#  '27: 122 93 | 54 103',
#  '4: 123 122 | 90 54',
#  '65: 122 87 | 54 22',
#  '113: 54 | 122',
#  '23: 122 127 | 54 62',
#  '117: 71 54 | 119 122',
#  '53: 35 54 | 126 122',
#  '26: 122 52 | 54 108',
#  '125: 54 33 | 122 4',
#  '10: 74 122 | 53 54',
#  '84: 54 19 | 122 109',
#  '123: 122 114 | 54 115',
#  '42: 70 122 | 26 54',
#  '16: 122 39 | 54 98',
#  '63: 98 54 | 51 122',
#  '39: 54 122',
#  '76: 122 83 | 54 101',
#  '61: 122 3 | 54 39',
#  '50: 122 85 | 54 95',
#  '78: 22 122 | 3 54',
#  '114: 122 122',
# ...
